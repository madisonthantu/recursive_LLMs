# %%
import sys
import os

root_dir = "/Users/madisonthantu/Desktop/COMS_6998/Final_Project/recursive_LLMs/src"
sys.path.append(os.path.abspath(root_dir))
from src.utils import *

import numpy as np
import pandas as pd

# %%
root_path = '/Users/madisonthantu/Desktop/COMS_6998/Final_Project/recursive_LLMs/results/experiment1'

dataset_names = ['dialogue', 'news', 'reddit']
dataset_results = {}
for k in dataset_names:
    dataset_results[k] = pd.read_pickle(os.path.join(root_path, k,'baseline', 'dataset_measurements.pkl'))

prettyprint_dict(dataset_results)
# Out:
# dialogue
# 	config
# 		base_model
# 		subject
# 		generation
# 		no_samples
# 		DEBUG
# 	metrics
# 		samples
# 		sample_idxs
# 		coverage
# 		compression_ratio
# 		summary_token_distribution
# 		formality_scores
# 		formality_sample_idxs
# 		toxicity_scores
# 		toxicity_sample_idxs
# 		formality_mean
# 		toxicity_mean
# 		emotion_intensity_mean
# 		emotion_intensity_measurements
# 	generation
# 	subject
# 	model
# news
# 	config
# 		base_model
# 		subject
# 		generation
# 		no_samples
# 		DEBUG
# 	metrics
# 		samples
# 		sample_idxs
# 		average_doc_toks
# 		average_summ_toks
# 		coverage
# 		compression_ratio
# 		summary_token_distribution
# 		formality_scores
# 		formality_sample_idxs
# 		toxicity_scores
# 		toxicity_sample_idxs
# 		formality_mean
# 		toxicity_mean
# 		emotion_intensity_mean
# 		emotion_intensity_measurements
# 	generation
# 	subject
# 	model
# 	no_total_samples
# 	no_training_samples
# 	no_validation_samples
# reddit
# 	config
# 		base_model
# 		subject
# ...

# %%
res_keys = list(dataset_results['dialogue']['metrics'].keys())
print(res_keys)
# Out:
# ['samples', 'sample_idxs', 'coverage', 'compression_ratio', 'summary_token_distribution', 'formality_scores', 'formality_sample_idxs', 'toxicity_scores', 'toxicity_sample_idxs', 'formality_mean', 'toxicity_mean', 'emotion_intensity_mean', 'emotion_intensity_measurements']

# %%
key = res_keys[1]
print(key, "\n")
# print(dataset_results['dialogue']['metrics']['summary_token_distribution'])
print(dataset_results['dialogue']['metrics']['emotion_intensity_measurements'])
# print(type(dataset_results['dialogue']['metrics']['emotion_intensity_measurements'].item()))
# print(list(dataset_results['dialogue']['metrics'][key]))
# Out:
# sample_idxs
#
# ...

# %%
for k, v in dataset_results['dialogue']['metrics']['emotion_intensity_measurements'].items():
    print(k, " - ", type(v))
# Out:
# id  -  <class 'dict'>
# weighted_avg  -  <class 'dict'>
# num_summary_tokens  -  <class 'dict'>
# trust_tok_cnt  -  <class 'dict'>
# trust_score_avg  -  <class 'dict'>
# surprise_tok_cnt  -  <class 'dict'>
# surprise_score_avg  -  <class 'dict'>
# sadness_tok_cnt  -  <class 'dict'>
# sadness_score_avg  -  <class 'dict'>
# joy_tok_cnt  -  <class 'dict'>
# joy_score_avg  -  <class 'dict'>
# fear_tok_cnt  -  <class 'dict'>
# fear_score_avg  -  <class 'dict'>
# disgust_tok_cnt  -  <class 'dict'>
# disgust_score_avg  -  <class 'dict'>
# anticipation_tok_cnt  -  <class 'dict'>
# anticipation_score_avg  -  <class 'dict'>
# anger_tok_cnt  -  <class 'dict'>
# anger_score_avg  -  <class 'dict'>

# %%
pd.DataFrame(dataset_results['dialogue']['metrics']['emotion_intensity_measurements'])
# Out:
#           id  weighted_avg  num_summary_tokens  trust_tok_cnt  \
# 0        944      0.052914                  35              1
# 1       3131      0.000000                  17              0
# 2       8730      0.037267                  15              0
# 3       2628      0.207556                   9              0
# 4       8860      0.144828                  29              1
# ...      ...           ...                 ...            ...
# 16364   3484      0.000000                  13              0
# 16365    522      0.048000                  14              1
# 16366  15327      0.035900                  10              0
# 16367   2039      0.017857                  21              0
# 16368   9750      0.000000                  11              0
#
#        trust_score_avg  surprise_tok_cnt  surprise_score_avg  sadness_tok_cnt  \
# 0                0.477                 0                 0.0                0
# ...

# %%
for k, v in dataset_results['news']['metrics'].items():
    print(k, "\n\t", type(v))
# Out:
# samples
# 	 <class 'pandas.core.series.Series'>
# sample_idxs
# 	 <class 'numpy.ndarray'>
# average_doc_toks
# 	 <class 'float'>
# average_summ_toks
# 	 <class 'float'>
# coverage
# 	 <class 'numpy.float64'>
# compression_ratio
# 	 <class 'numpy.float64'>
# summary_token_distribution
# 	 <class 'nltk.probability.FreqDist'>
# formality_scores
# 	 <class 'numpy.ndarray'>
# formality_sample_idxs
# 	 <class 'numpy.ndarray'>
# toxicity_scores
# 	 <class 'numpy.ndarray'>
# toxicity_sample_idxs
# 	 <class 'numpy.ndarray'>
# formality_mean
# 	 <class 'numpy.float64'>
# toxicity_mean
# 	 <class 'numpy.float64'>
# emotion_intensity_mean
# 	 <class 'numpy.float64'>
# emotion_intensity_measurements
# 	 <class 'dict'>
